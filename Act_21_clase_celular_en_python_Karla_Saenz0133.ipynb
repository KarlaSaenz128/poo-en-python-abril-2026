# %% [markdown]
# <a href="https://colab.research.google.com/github/KarlaSaenz128/poo-en-python-abril-2026/blob/main/Act_21_clase_celular_en_python_Karla_Saenz0133.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Karla Saenz NL = 48 FECHA 22/abril/2026
# ## Clase celular
# ![texto del vínculo](https://raw.githubusercontent.com/KarlaSaenz128/ACT21-clase-celular-python-FECHA-abril-2026/refs/heads/main/infoclasecelular.png)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# Instanciación
cel1 = Celular("Samsung", "Galaxy S23", 800)
cel2 = Celular("Apple", "iPhone 15", 1000)
# llamada a las funciones para cada objeto celular 1 y celular 2
print("Celular 1:")
cel1.mostrar_info()
cel1.encender()
print("\nCelular 2:")
cel2.mostrar_info()
cel2.encender()

print("programa terminado")
print("Creador de software por Karla Saenz NL = 48")
# Out:
# Celular 1:
# Celular: Samsung Galaxy S23, Precio: $800
# El Galaxy S23 se ha encendido.
#
# Celular 2:
# Celular: Apple iPhone 15, Precio: $1000
# El iPhone 15 se ha encendido.
# programa terminado
# Creador de software por Karla Saenz NL = 48

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/KarlaSaenz128/ACT21-clase-celular-python-FECHA-abril-2026/refs/heads/main/logiaFuncionamiento.png)
